# %%
import requests
from bs4 import BeautifulSoup
import json
import time

# %%
CATALOG_URL = "https://www.africa.engineering.cmu.edu/academics/course-catalog.html"
BASE_URL = "https://www.africa.engineering.cmu.edu"

def get_available_course_links():
    resp = requests.get(CATALOG_URL)
    soup = BeautifulSoup(resp.text, "html.parser")

    # Find the header "Available Courses"
    available_header = soup.find("h2", string="Available courses")
    if not available_header:
        raise Exception("Could not find Available Courses section")

    # Find the next table after the header
    table = available_header.find_next("table")
    if not table:
        raise Exception("Could not find the courses table after the header")

    links = []
    for row in table.find_all("tr"):
        first_td = row.find("td")
        if first_td:
            a_tag = first_td.find("a", href=True)
            if a_tag and a_tag["href"].endswith(".html"):
                href = a_tag["href"]
                # Make absolute URL
                if href.startswith("/"):
                    full_url = BASE_URL + href
                else:
                    full_url = BASE_URL + "/academics/" + href
                links.append(full_url)
    return links

# %%
def parse_course_page(url):
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, "html.parser")

    h1 = soup.find("h1")
    title_raw = h1.get_text(strip=True) if h1 else ""
    title_raw = title_raw.replace("\xa0", "").strip()
    if " " in title_raw:
        course_code, title = title_raw.split(" ", 1)
        title=title.strip()
    else:
        course_code = ""
        title = title_raw

    # Extract course info block
    info_block = soup.find("p", class_="mb-month")
    semester = units = location = None
    if info_block:
        text = info_block.get_text()
        for line in text.splitlines():
            line = line.strip()
            if "Semester Offered" in line:
                semester = line.split(":")[1].strip()
            elif "Units" in line:
                units = line.split(":")[1].strip()
            elif "Location" in line:
                location = line.split(":")[1].strip()

    # Initialize content
    course_data = {
        "url": url,
        "course_code": course_code,
        "title": title,
        "semester": semester,
        "units": units,
        "location": location,
        "description": "",
        "objectives": "",
        "outcomes": [],
        "content": "",
        "prerequisites": []
    }

    # Section detection
    content_wrapper = soup.find("section", class_="innerSection")
    if content_wrapper:
        current_section = None
        for tag in content_wrapper.find_all(["h2", "p", "ul"]):
            tag_text = tag.get_text(strip=True).lower()
            if tag.name == "h2":
                if "description" in tag_text:
                    current_section = "description"
                elif "objective" in tag_text:
                    current_section = "objectives"
                elif "outcome" in tag_text:
                    current_section = "outcomes"
                elif "content" in tag_text:
                    current_section = "content"
                elif "prerequisite" in tag_text:
                    current_section = "prerequisites"
                else:
                    current_section = None
            elif tag.name == "p":
                text = tag.get_text(" ", strip=True)
                if current_section == "description":
                    course_data["description"] += text + " "
                elif current_section == "objectives":
                    course_data["objectives"] += text + " "
                elif current_section == "content":
                    course_data["content"] += text + " "
                elif current_section == "prerequisites":
                    # Try extracting course codes or names from text
                    course_data["prerequisites"] += [
                        p.strip() for p in text.split(",") if p.strip()
                    ]
            elif tag.name == "ul" and current_section == "outcomes":
                course_data["outcomes"] += [
                    li.get_text(" ", strip=True) for li in tag.find_all("li")
                ]

    return course_data

# %%
def main():
    links = get_available_course_links()
    print(f"Found {len(links)} available courses.")
    
    all_courses = []
    for i, link in enumerate(links):
        print(f"[{i+1}/{len(links)}] Scraping {link}")
        try:
            course = parse_course_page(link)
            all_courses.append(course)
            time.sleep(1)  # we must be nice to the server
        except Exception as e:
            print(f"⚠️ Error scraping {link}: {e}")

    with open("cmuafrica_courses.json", "w", encoding="utf-8") as f:
        json.dump(all_courses, f, indent=2, ensure_ascii=False)

    print("✅ Scraping completed. Saved to cmuafrica_courses.json")

# %%
main()
# Out:
# Found 105 available courses.
# [1/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-330.html
# [2/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-601.html
# [3/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-603.html
# [4/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-605.html
# [5/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-606.html
# [6/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-607.html
# [7/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-608.html
# [8/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-609.html
# [9/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-611.html
# [10/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-612.html
# [11/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-613.html
# [12/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-616.html
# [13/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-622.html
# [14/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-623.html
# [15/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-624.html
# [16/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-625.html
# [17/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-630.html
# [18/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-631.html
# [19/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-632.html
# [20/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-633.html
# [21/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-634.html
# [22/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-636.html
# [23/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-637.html
# [24/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-638.html
# [25/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-641.html
# [26/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-645.html
# [27/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-650.html
# [28/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-651.html
# [29/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-652.html
# [30/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-653.html
# [31/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-654.html
# [32/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-655.html
# [33/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-701.html
# [34/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-720.html
# [35/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-730.html
# [36/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-762.html
# [37/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-801-V3.html
# [38/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-800-AF.html
# [39/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-800-AG.html
# [40/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-800-AH.html
# [41/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-801-A1.html
# [42/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-761.html
# [43/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-732.html
# [44/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-617.html
# [45/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-800-G.html
# [46/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-800-H.html
# [47/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-800-I.html
# [48/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-800-J.html
# [49/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-800-K.html
# [50/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-801-N1.html
# [51/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-801-O3.html
# [52/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-801-O4.html
# [53/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-801-S3.html
# [54/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-801-S4.html
# [55/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-801-T3.html
# [56/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-801-T4.html
# [57/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-801-U3.html
# [58/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-900.html
# [59/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-910.html
# [60/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-950.html
# [61/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-980.html
# [62/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/04-990.html
# [63/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/11-611.html
# [64/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/11-697.html
# [65/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/11-741.html
# [66/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/11-785.html
# [67/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/11-797-R.html
# [68/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/14-735.html
# [69/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/14-817.html
# [70/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/15-619.html
# [71/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/17-734.html
# [72/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-662.html
# [73/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-631.html
# [74/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-640.html
# [75/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-641.html
# [76/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-652.html
# [77/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-661.html
# [78/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-681.html
# [79/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-685.html
# [80/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-731.html
# [81/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-751.html
# [82/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-759.html
# [83/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-785.html
# [84/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-787-K3.html
# [85/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-788-K4.html
# [86/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-797.html
# [87/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-799-L.html
# [88/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-799-RW.html
# [89/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-859-R.html
# [90/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-861.html
# [91/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-862.html
# [92/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-863-K3.html
# [93/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-864-R4.html
# [94/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-865.html
# [95/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-866-M3.html
# [96/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-867-R4.html
# [97/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-883-L4.html
# [98/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-980.html
# [99/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/18-989.html
# [100/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/19-608.html
# [101/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/19-625.html
# [102/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/19-661-RW.html
# [103/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/24-784.html
# [104/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/90-834.html
# [105/105] Scraping https://www.africa.engineering.cmu.edu/academics/courses/94-802.html
# ✅ Scraping completed. Saved to cmuafrica_courses.json

# %%
with open("cmuafrica_courses.json", "r", encoding="utf-8") as f:
    courses = json.load(f)
    print(f"Number of courses in cmuafrica_courses.json: {len(courses)}")
# Out:
# Number of courses in cmuafrica_courses.json: 105
